# %% [markdown]
# <a href="https://colab.research.google.com/github/heesukjang/W209_DataViz_Summer2023/blob/main/Unit_Assignments/03_01_setting_up_altair.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 3 Assignment
# **W209 Section 6**<br>
# **Heesuk Jang**

# %%
import altair as alt
from IPython.display import Image
# alt.data_tranformers.enable("json")   # when work with a lot of data

# %%
from vega_datasets import data

seattle_weather = data.seattle_weather()
seattle_weather.head()
# Out:
#         date  precipitation  temp_max  temp_min  wind  weather
# 0 2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1 2012-01-02           10.9      10.6       2.8   4.5     rain
# 2 2012-01-03            0.8      11.7       7.2   2.3     rain
# 3 2012-01-04           20.3      12.2       5.6   4.7     rain
# 4 2012-01-05            1.3       8.9       2.8   6.1     rain

# %%
alt.__version__
# Out:
# '4.2.2'

# %% [markdown]
# ## **Scatterplot:** temp_max by temp_min

# %%
# alt.Chart(seattle_weather).mark_point().encode(
alt.Chart(seattle_weather).mark_circle().encode(
    x='temp_max',
    y='temp_min',
    color='weather',
    tooltip=['weather','temp_max','temp_min']
).interactive()
# Out:
# alt.Chart(...)

# %% [markdown]
# ## Add a screenshot of the scatterplot to make sure it's visible for the peer review

# %%
Image('/content/scatterplot.png', width=600, height=400)

# %%
print(alt.Chart(seattle_weather).mark_circle().encode(
    x='temp_max',
    y='temp_min',
    color='weather',
    tooltip=['weather','temp_max','temp_min']
).to_json())
# Out:
# {
#   "$schema": "https://vega.github.io/schema/vega-lite/v4.17.0.json",
#   "config": {
#     "view": {
#       "continuousHeight": 300,
#       "continuousWidth": 400
#     }
#   },
#   "data": {
#     "name": "data-830c39fec90146253fb06a06c26374ef"
#   },
#   "datasets": {
#     "data-830c39fec90146253fb06a06c26374ef": [
#       {
#         "date": "2012-01-01T00:00:00",
#         "precipitation": 0.0,
#         "temp_max": 12.8,
#         "temp_min": 5.0,
#         "weather": "drizzle",
#         "wind": 4.7
#       },
#       {
#         "date": "2012-01-02T00:00:00",
#         "precipitation": 10.9,
#         "temp_max": 10.6,
#         "temp_min": 2.8,
#         "weather": "rain",
#         "wind": 4.5
#       },
#       {
#         "date": "2012-01-03T00:00:00",
#         "precipitation": 0.8,
#         "temp_max": 11.7,
#         "temp_min": 7.2,
#         "weather": "rain",
#         "wind": 2.3
#       },
#       {
#         "date": "2012-01-04T00:00:00",
# ...
